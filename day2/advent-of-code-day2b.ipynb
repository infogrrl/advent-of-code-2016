# %%
x = '9'
#input = '...'
#input = '...'
#input = '...'
#input = '...'
input = '...'

for i in input:
    #print(i)
    if (x == '1'):
        if (i == 'L'):
            x = '1'
        elif (i == 'R'):
            x = '1'
        elif (i == 'U'):
            x = '1'
        elif (i == 'D'):
            x = '3'
    elif (x == '2'):
        if (i == 'L'):
            x = '2'
        elif (i == 'R'):
            x = '3'
        elif (i == 'U'):
            x = '2'
        elif (i == 'D'):
            x = '6'
    elif (x == '3'):
        if (i == 'L'):
            x = '2'
        elif (i == 'R'):
            x = '4'
        elif (i == 'U'):
            x = '1'
        elif (i == 'D'):
            x = '7'
    elif (x == '4'):
        if (i == 'L'):
            x = '3'
        elif (i == 'R'):
            x = '4'
        elif (i == 'U'):
            x = '4'
        elif (i == 'D'):
            x = '8'
    elif (x == '5'):
        if (i == 'L'):
            x = '5'
        elif (i == 'R'):
            x = '6'
        elif (i == 'U'):
            x = '5'
        elif (i == 'D'):
            x = '5'
    elif (x == '6'):
        if (i == 'L'):
            x = '5'
        elif (i == 'R'):
            x = '7'
        elif (i == 'U'):
            x = '2'
        elif (i == 'D'):
            x = 'A'
    elif (x == '7'):
        if (i == 'L'):
            x = '6'
        elif (i == 'R'):
            x = '8'
        elif (i == 'U'):
            x = '3'
        elif (i == 'D'):
            x = 'B'
    elif (x == '8'):
        if (i == 'L'):
            x = '7'
        elif (i == 'R'):
            x = '9'
        elif (i == 'U'):
            x = '4'
        elif (i == 'D'):
            x = 'C'
    elif (x == '9'):
        if (i == 'L'):
            x = '8'
        elif (i == 'R'):
            x = '9'
        elif (i == 'U'):
            x = '9'
        elif (i == 'D'):
            x = '9'
    elif (x == 'A'):
        if (i == 'L'):
            x = 'A'
        elif (i == 'R'):
            x = 'B'
        elif (i == 'U'):
            x = '6'
        elif (i == 'D'):
            x = 'A'
    elif (x == 'B'):
        if (i == 'L'):
            x = 'A'
        elif (i == 'R'):
            x = 'C'
        elif (i == 'U'):
            x = '7'
        elif (i == 'D'):
            x = 'D'
    elif (x == 'C'):
        if (i == 'L'):
            x = 'B'
        elif (i == 'R'):
            x = 'C'
        elif (i == 'U'):
            x = '8'
        elif (i == 'D'):
            x = 'C'
    elif (x == 'D'):
        if (i == 'L'):
            x = 'D'
        elif (i == 'R'):
            x = 'D'
        elif (i == 'U'):
            x = 'B'
        elif (i == 'D'):
            x = 'D'           
    #print(x)
print(x)
# Out:
# 2

# %%
46C92
