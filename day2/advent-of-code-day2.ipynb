# %%
x = 5
input = '...'

for i in input:
    print(i)
    if (i == 'L'):
        if (x == 1):
            x = 1
        elif (x == 2):
            x = 1
        elif (x == 3):
            x = 2
        elif (x == 4):
            x = 4
        elif (x == 5):
            x = 4
        elif (x == 6):
            x = 5
        elif (x == 7):
            x = 7
        elif (x == 8):
            x = 7
        elif (x == 9):
            x = 8
    elif (i == 'R'):
        if (x == 1):
            x = 2
        elif (x == 2):
            x = 3
        elif (x == 3):
            x = 3
        elif (x == 4):
            x = 5
        elif (x == 5):
            x = 6
        elif (x == 6):
            x = 6
        elif (x == 7):
            x = 8
        elif (x == 8):
            x = 9
        elif (x == 9):
            x = 9
    elif (i == 'U'):
        if (x == 1):
            x = 1
        elif (x == 2):
            x = 2
        elif (x == 3):
            x = 3
        elif (x == 4):
            x = 1
        elif (x == 5):
            x = 2
        elif (x == 6):
            x = 3
        elif (x == 7):
            x = 4
        elif (x == 8):
            x = 5
        elif (x == 9):
            x = 6
    elif (i == 'D'):
        if (x == 1):
            x = 4
        elif (x == 2):
            x = 5
        elif (x == 3):
            x = 6
        elif (x == 4):
            x = 7
        elif (x == 5):
            x = 8
        elif (x == 6):
            x = 9
        elif (x == 7):
            x = 7
        elif (x == 8):
            x = 8
        elif (x == 9):
            x = 9
    print(x)
# Out:
# U
# 2
# D
# 5
# D
# 8
# D
# 8
# R
# 9
# L
# 8
# D
# 8
# R
# 9
# D
# 9
# U
# 6
# L
# 5
# D
# 8
# R
# 9
# L
# 8
# R
# 9
# D
# 9
# U
# 6
# D
# 9
# D
# 9
# L
# 8
# D
# 8
# L
# 7
# L
# 7
# D
# 7
# D
# 7
# L
# 7
# U
# 4
# U
# 1
# U
# 1
# R
# 2
# D
# 5
# D
# 8
# D
# 8
# L
# 7
# U
# 4
# D
# 7
# R
# 8
# D
# 8
# U
# 5
# D
# 8
# L
# 7
# D
# 7
# U
# 4
# R
# 5
# L
# 4
# U
# 1
# U
# 1
# R
# 2
# U
# 2
# D
# 5
# U
# 2
# U
# 2
# L
# 1
# U
# 1
# U
# 1
# U
# 1
# L
# 1
# D
# 4
# U
# 1
# U
# 1
# R
# 2
# L
# 1
# U
# 1
# L
# 1
# L
# 1
# R
# 2
# L
# 1
# U
# 1
# D
# 4
# L
# 4
# L
# 4
# U
# 1
# R
# 2
# U
# 2
# U
# 2
# U
# 2
# U
# 2
# L
# 1
# R
# 2
# L
# 1
# R
# 2
# L
# 1
# L
# 1
# L
# 1
# R
# 2
# R
# 3
# L
# 2
# U
# 2
# L
# 1
# L
# 1
# D
# 4
# R
# 5
# U
# 2
# U
# 2
# L
# 1
# U
# 1
# R
# 2
# R
# 3
# L
# 2
# L
# 1
# U
# 1
# D
# 4
# U
# 1
# D
# 4
# U
# 1
# R
# 2
# U
# 2
# L
# 1
# L
# 1
# L
# 1
# R
# 2
# R
# 3
# R
# 3
# R
# 3
# L
# 2
# R
# 3
# U
# 3
# U
# 3
# L
# 2
# L
# 1
# R
# 2
# D
# 5
# R
# 6
# D
# 9
# R
# 9
# ...

# %%
38961
